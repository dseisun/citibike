# %%
from helpers import get_sample_file
import pandas as pd

# %%
df = get_sample_file(top_1000=True)

# %%
df['test'] = 'test'

# %%
df
# Out:
#               ride_id  rideable_type           started_at  \
# 0    C09E4093905089BD   classic_bike  2022-07-23 11:34:57
# 1    374630DB5822C392  electric_bike  2022-07-29 18:19:08
# 2    4F73CA25880A1215  electric_bike  2022-07-16 16:30:58
# 3    ECD6EE19C0CC1D31  electric_bike  2022-07-17 17:35:57
# 4    44D0987673B9997D   classic_bike  2022-07-11 07:56:29
# ..                ...            ...                  ...
# 995  0F87E6AA53284B9F   classic_bike  2022-07-04 13:37:48
# 996  3B433CD081477953  electric_bike  2022-07-24 04:47:36
# 997  5CFE90B3DCDFC7DE   classic_bike  2022-07-02 20:21:59
# 998  EC034412314B3701  electric_bike  2022-07-01 07:39:09
# 999  8B2AA9CC110BBC8A   classic_bike  2022-07-31 17:03:40
#
#                 ended_at         start_station_name  start_station_id  \
# 0    2022-07-23 11:45:08      Melrose St & Broadway           4801.04
# 1    2022-07-29 18:26:50            E 68 St & 3 Ave           6896.16
# ...

# %%
df_full.dtypes

# %%
df2 = df_full.groupby(['start_station_id'])\
[['start_lat', 'start_lng', 'started_at', 'ended_at', 'start_station_name']]\
.agg({'start_station_name': 'min', 'start_lat': 'mean', 'start_lng': 'mean', 'started_at': 'min', 'ended_at': 'max'})

# %%
current_stations = pd.read_sql_table('stations', schema='prod', con=verbose_engine)

# %%
current_stations = current_stations.astype({'station_name': 'string', 'citi_station_id': 'string'})

# %%
current_stations.set_index(['station_name', 'citi_station_id'])

# %%
df2.index.names = ['citi_station_id']

# %%
df2

# %%
{x.pop('citi_station_id'): x for x in df2.reset_index().to_dict('records')}
